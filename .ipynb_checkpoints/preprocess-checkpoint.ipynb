# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in /home/irul/.local/lib/python3.9/site-packages (1.3.5)
# Requirement already satisfied: numpy>=1.17.3 in /home/irul/.local/lib/python3.9/site-packages (from pandas) (1.22.1)
# Requirement already satisfied: pytz>=2017.3 in /home/irul/anaconda3/lib/python3.9/site-packages (from pandas) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/irul/.local/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /home/irul/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('tweet.csv')
df
# Out:
#                id                                               text
# 0    1.572150e+18  So sorry... medsos lebih sehat jaman sby, ga a...
# 1    1.572150e+18  Ini ketua umum partai gue.. Muda, Cerdas, Prog...
# 2    1.572150e+18                     @AndiSinulingga cebong muka 2.
# 3    1.572150e+18  RT @maspiyuaja: Timses Jokowi-Ma'ruf Amin Jadi...
# 4    1.572150e+18  Saat SBY hadir rapimnas kemarin beliau kembali...
# ..            ...                                                ...
# 194  1.572150e+18  @erickthohir @jokowi @indonesiaport https://t....
# 195  1.572150e+18  14 Fakta Prestasi AHY yang Perlu Diketahui #Ma...
# 196  1.572150e+18  Partai Demokrat Ungkap Terima Intimidasi setel...
# 197  1.572150e+18  Deretan Prestasi AHY yang tidak banyak diketah...
# 198  1.572150e+18  Merinding rasanya menjadi saksi sejarah pada R...
#
# [199 rows x 2 columns]

# %%
df = df.drop(['id'], axis=1)

# %%
import re

# %%
def preprocess_tweet(tweet):
    
    sentence = tweet.lower()

    # Remove RT
    sentence = re.sub('rt @\w+: '," ", sentence)

    # Remove punctuations and numbers
    sentence = re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)"," ", sentence)

    # Single character removal
    sentence = re.sub(r"\s+[a-zA-Z]\s+", ' ', sentence)  # When we remove apostrophe from the word "Mark's", the apostrophe is replaced by an empty space. Hence, we are left with single character "s" that we are removing here.

    # Remove multiple spaces
    sentence = re.sub(r'\s+', ' ', sentence)  # Next, we remove all the single characters and replace it by a space which creates multiple spaces in our text. Finally, we remove the multiple spaces from our text as well.

    return sentence

# %%
df['tweet'] = df[ 'text'].apply(lambda x: preprocess_tweet(x))

# %%
df
# Out:
#                                                   text  \
# 0    So sorry... medsos lebih sehat jaman sby, ga a...
# 1    Ini ketua umum partai gue.. Muda, Cerdas, Prog...
# 2                       @AndiSinulingga cebong muka 2.
# 3    RT @maspiyuaja: Timses Jokowi-Ma'ruf Amin Jadi...
# 4    Saat SBY hadir rapimnas kemarin beliau kembali...
# ..                                                 ...
# 194  @erickthohir @jokowi @indonesiaport https://t....
# 195  14 Fakta Prestasi AHY yang Perlu Diketahui #Ma...
# 196  Partai Demokrat Ungkap Terima Intimidasi setel...
# 197  Deretan Prestasi AHY yang tidak banyak diketah...
# 198  Merinding rasanya menjadi saksi sejarah pada R...
#
#                                                  tweet
# 0    so sorry medsos lebih sehat jaman sby ga ada b...
# 1    ini ketua umum partai gue muda cerdas progresi...
# 2                                       cebong muka 2
# 3     timses jokowi ma ruf amin jadi tersangka kpk ...
# 4    saat sby hadir rapimnas kemarin beliau kembali...
# ..                                                 ...
# 194
# 195  14 fakta prestasi ahy yang perlu diketahui mak...
# 196  partai demokrat ungkap terima intimidasi setel...
# 197  deretan prestasi ahy yang tidak banyak diketah...
# 198  merinding rasanya menjadi saksi sejarah pada r...
#
# [199 rows x 2 columns]
